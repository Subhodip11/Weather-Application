# %%
import os
files = os.listdir("./weather_code_mapped_icons")
files
# Out:
# ['10000_clear_small.png',
#  '10000_clear_small@2x.png',
#  '10001_clear_small.png',
#  '10001_clear_small@2x.png',
#  '10010_cloudy_small.png',
#  '10010_cloudy_small@2x.png',
#  '11000_mostly_clear_small.png',
#  '11000_mostly_clear_small@2x.png',
#  '11001_mostly_clear_small.png',
#  '11001_mostly_clear_small@2x.png',
#  '11010_partly_cloudy_small.png',
#  '11010_partly_cloudy_small@2x.png',
#  '11011_partly_cloudy_small.png',
#  '11011_partly_cloudy_small@2x.png',
#  '11020_mostly_cloudy_small.png',
#  '11020_mostly_cloudy_small@2x.png',
#  '11021_mostly_cloudy_small.png',
#  '11021_mostly_cloudy_small@2x.png',
#  '11030_mostly_clear_small.png',
#  '11030_mostly_clear_small@2x.png',
#  '11031_mostly_clear_small.png',
#  '11031_mostly_clear_small@2x.png',
#  '20000_fog_small.png',
#  '20000_fog_small@2x.png',
#  '21000_fog_light_small.png',
#  '21000_fog_light_small@2x.png',
#  '21010_fog_light_mostly_clear_small.png',
#  '21010_fog_light_mostly_clear_small@2x.png',
# ...
